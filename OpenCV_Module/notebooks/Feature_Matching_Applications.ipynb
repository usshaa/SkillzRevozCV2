# %% [markdown]
# # Feature Matching & Applications
#
# Objective: Match features between two images and demonstrate applications.
# Analogy: Like matching puzzle pieces to recreate the image.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('cartoon2.jpg')
img2 = cv2.imread('cartoon1.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
sift = cv2.SIFT_create()
kp1, des1 = sift.detectAndCompute(gray1, None)
kp2, des2 = sift.detectAndCompute(gray2, None)

# %%
bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)
matches = bf.match(des1, des2)
matches = sorted(matches, key=lambda x: x.distance)
img_matches = cv2.drawMatches(img1, kp1, img2, kp2, matches[:20], None, flags=2)
plt.imshow(cv2.cvtColor(img_matches, cv2.COLOR_BGR2RGB))
plt.title('Top 20 Feature Matches')
plt.show()

# %% [markdown]
# ### Applications
# - Panorama stitching using matched features
# - Object recognition
# - AR / VR / Robotics

# %% [markdown]
# ### Summary
# - Image processing prepares images for analysis
# - Feature detection identifies unique points
# - Feature matching links images for object recognition and stitching
# - Applications: AR, robotics, self-driving cars, tracking
